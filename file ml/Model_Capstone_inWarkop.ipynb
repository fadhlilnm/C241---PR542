# %%
# !pip install tensorflow_recommenders
# Out:
# Collecting tensorflow_recommenders
#   Downloading tensorflow_recommenders-0.7.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow_recommenders) (1.4.0)
# Requirement already satisfied: tensorflow>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_recommenders) (2.15.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.9.0->tensorflow_recommenders) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (3.2.2)
# Installing collected packages: tensorflow_recommenders
# Successfully installed tensorflow_recommenders-0.7.3

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_recommenders as tfrs
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
warkop_df = pd.read_csv('https://storage.googleapis.com/inwarkop-bucket/all%20warkop2.csv')

#encode categorical features
# label_encoder_region = LabelEncoder()
# warkop_df['region_encoded'] = label_encoder_region.fit_transform(warkop_df['region'])

facilities_set = set()
for facilities in warkop_df['facilities']:
    facilities_set.update(facilities.split(','))

for facility in facilities_set:
    warkop_df[facility] = warkop_df['facilities'].apply(lambda x: 1 if facility in x else 0)

# Normalize ratings
warkop_df['rating_normalized'] = warkop_df['rating'] / warkop_df['rating'].max()

# %%
warkop_df.head()
# Out:
#    warkop_id                                    name  \
# 0          1                        WARKOP 2 SAUDARA
# 1          2                Warkop Selamat Sejahtera
# 2          3                        Warkop Been Aouf
# 3          4                             Warkop otoy
# 4          5  Warkop Barokah masjid jami'e darusalam
#
#                                              address  rating  rating_count  \
# 0  Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta     4.5             2
# 1               Jl. Kebon Kacang 30 No.15, RT.5/RW.4     4.5             2
# 2                Jl. Kb. Kacang XL No.24, RT.10/RW.4     4.5            68
# 3                           Jl. Kebon Kacang 30 No.7     5.0             3
# 4  Masjid Darussalam, Jl. Kotabumi Ujung No.Depan...     4.5             2
#
#   region                   facilities  24hours  parking  wifi  ac  toilet  \
# 0  Pusat  24hours,wifi,toilet,parking        1        1     1   0       1
# 1  Pusat                  wifi,toilet        0        0     1   0       1
# 2  Pusat               toilet,parking        0        1     0   0       1
# 3  Pusat               toilet,parking        0        1     0   0       1
# 4  Pusat              24hours,parking        1        1     0   0       0
#
#    rating_normalized
# 0                0.9
# 1                0.9
# 2                0.9
# 3                1.0
# 4                0.9

# %%
warkop_df["region"].unique()
# Out:
# array(['Pusat', 'Barat', 'Timur', 'Selatan', 'Utara'], dtype=object)

# %%
class WarkopModel(tfrs.Model):

    def __init__(self):
        super().__init__()
        embedding_dim = 32

        # # Item model for facilities embeddings
        self.facilities_embedding = tf.keras.Sequential([
            tf.keras.layers.DenseFeatures([
                tf.feature_column.numeric_column(facility) for facility in facilities_set
            ]),
            tf.keras.layers.Dense(embedding_dim)
        ])

        # Rating prediction model
        self.rating_normalized = tf.keras.Sequential([
            tf.keras.layers.Dense(1)
        ])

        # Task setup
        self.task = tfrs.tasks.Ranking(
            loss = tf.keras.losses.BinaryCrossentropy(),
            metrics = [tf.keras.metrics.BinaryCrossentropy()]
        )

    def call(self, features):
        facilities_embeddings = self.facilities_embedding(features)
        return self.rating_normalized(facilities_embeddings)

    def compute_loss(self, features, training=False):
        labels = features.pop("rating_normalized")
        predictions = self(features)
        return self.task(labels=labels, predictions=predictions)

# %%
# Prepare the data

# Split the data into train and test sets
train, test = train_test_split(warkop_df, test_size=0.2, random_state=42)

def preprocess(df):
    features = {name: np.array(value) for name, value in df.items()}
    return features

train = preprocess(train)
test = preprocess(test)

# Define the data pipeline
train = tf.data.Dataset.from_tensor_slices((train)).batch(32)
test = tf.data.Dataset.from_tensor_slices((test)).batch(32)

# Initialize and compile the model

# Compile the model
model = WarkopModel()
model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate=1e-2))

# Train the model with Early Stopping
history = model.fit(train, epochs=100)

# Evaluate the model
model.evaluate(test)
# Out:
# WARNING:tensorflow:From <ipython-input-6-9d810e5acf39>:10: numeric_column (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Keras preprocessing layers instead, either directly or via the `tf.keras.utils.FeatureSpace` utility. Each of `tf.feature_column.*` has a functional equivalent in `tf.keras.layers` for feature preprocessing when training a Keras model.
# Epoch 1/100
# 7/7 [==============================] - 3s 14ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 2/100
# 7/7 [==============================] - 0s 14ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 3/100
# 7/7 [==============================] - 0s 17ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 4/100
# 7/7 [==============================] - 0s 13ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 5/100
# 7/7 [==============================] - 0s 18ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 6/100
# 7/7 [==============================] - 0s 9ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 7/100
# 7/7 [==============================] - 0s 5ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 8/100
# 7/7 [==============================] - 0s 14ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 9/100
# 7/7 [==============================] - 0s 10ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 10/100
# 7/7 [==============================] - 0s 13ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 11/100
# 7/7 [==============================] - 0s 15ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 12/100
# 7/7 [==============================] - 0s 11ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 13/100
# 7/7 [==============================] - 0s 13ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 14/100
# 7/7 [==============================] - 0s 9ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 15/100
# 7/7 [==============================] - 0s 6ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 16/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 17/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 18/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 19/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 20/100
# 7/7 [==============================] - 0s 5ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 21/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 22/100
# 7/7 [==============================] - 0s 6ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 23/100
# 7/7 [==============================] - 0s 6ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 24/100
# 7/7 [==============================] - 0s 8ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 25/100
# 7/7 [==============================] - 0s 6ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 26/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 27/100
# 7/7 [==============================] - 0s 12ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 28/100
# 7/7 [==============================] - 0s 15ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 29/100
# 7/7 [==============================] - 0s 7ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 30/100
# 7/7 [==============================] - 0s 5ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 31/100
# 7/7 [==============================] - 0s 6ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 32/100
# 7/7 [==============================] - 0s 12ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 33/100
# 7/7 [==============================] - 0s 6ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 34/100
# 7/7 [==============================] - 0s 6ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 35/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 36/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 37/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 38/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 39/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 40/100
# 7/7 [==============================] - 0s 5ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 41/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 42/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 43/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 44/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 45/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 46/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 47/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 48/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 49/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 50/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 51/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 52/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 53/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 54/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 55/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 56/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 57/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 58/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 59/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 60/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 61/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 62/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 63/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 64/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 65/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 66/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 67/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 68/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 69/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 70/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 71/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 72/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 73/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 74/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 75/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 76/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 77/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 78/100
# 7/7 [==============================] - 0s 2ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 79/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 80/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 81/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 82/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 83/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 84/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 85/100
# 7/7 [==============================] - 0s 2ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 86/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 87/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 88/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 89/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 90/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 91/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 92/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 93/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 94/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 95/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 96/100
# 7/7 [==============================] - 0s 4ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 97/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 98/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 99/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# Epoch 100/100
# 7/7 [==============================] - 0s 3ms/step - binary_crossentropy: 14.4678 - loss: 14.4910 - regularization_loss: 0.0000e+00 - total_loss: 14.4910
# 2/2 [==============================] - 0s 8ms/step - binary_crossentropy: 14.4015 - loss: 14.3367 - regularization_loss: 0.0000e+00 - total_loss: 14.3367
# [14.40152359008789, 14.20719051361084, 0, 14.20719051361084]

# %%
import matplotlib.pyplot as plt
# Extract training and validation metrics
train_loss = history.history['loss']
val_loss = history.history['val_loss']
# train_accuracy = history.history['binary_accuracy']
# val_accuracy = history.history['val_binary_accuracy']

# Plot Loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot Accuracy
# plt.subplot(1, 2, 2)
# plt.plot(train_accuracy, label='Training Accuracy')
# plt.plot(val_accuracy, label='Validation Accuracy')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.title('Training and Validation Accuracy')
# plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-98973680e80a> in <cell line: 4>()
#       2 # Extract training and validation metrics
#       3 train_loss = history.history['loss']
# ----> 4 val_loss = history.history['val_loss']
#       5 # train_accuracy = history.history['binary_accuracy']
#       6 # val_accuracy = history.history['val_binary_accuracy']
#
# KeyError: 'val_loss'

# %%
def recommend_warkop(input_features, top_k=50):
    # Create a copy of the DataFrame to avoid modifying the original
    warkop_df_copy = warkop_df.copy()

    # Convert input features to tensor
    input_features_tensor = {
        facility: tf.convert_to_tensor([input_features.get(facility, 0)], dtype=tf.float32)
        for facility in facilities_set
    }

    # Get predictions for all warkops
    warkop_inputs = {
        facility: tf.convert_to_tensor(warkop_df_copy[facility].values.reshape(-1, 1), dtype=tf.float32)
        for facility in facilities_set
    }

    predictions = model(warkop_inputs)

    # Add predictions to the copy DataFrame
    warkop_df_copy['prediction'] = predictions.numpy().flatten()

    # Filter warkops by input facilities
    for facility in facilities_set:
        if input_features.get(facility, 1) == 1:
            warkop_df_copy = warkop_df_copy[warkop_df_copy[facility] == 1]

    # Sort warkops by prediction score and then by rating
    sorted_warkops = warkop_df_copy.sort_values(by=['prediction', 'rating'], ascending=[False, False]).head(top_k)

    # Select the columns to return
    output_columns = ['name', 'rating', 'address','region'] + list(facilities_set)
    return sorted_warkops[output_columns]

# %%
# Example input features for recommendation
input_features = {
    "wifi": 1,
    "24hours": 1,
    "ac": 1,
    "toilet": 1,
    "parking": 1
}

#Region filter
region = 'Barat'
recommended_warkops = recommend_warkop(input_features)
filtered_warkops = recommended_warkops.loc[warkop_df['region'] == region].copy()

# Get recommendations
# recommended_warkops
filtered_warkops
# Out:
#                       name  rating  \
# 64      Warkop Ujung Aspal     5.0
# 69       Warkop Rasa Rindu     5.0
# 80        Warkop bang udin     5.0
# 81             Warkop BASS     5.0
# 82        WARKOP MPOK NUNG     5.0
# 62  Warkop Ropang Rai Raka     4.9
# 51          Warkop Edo/edi     4.5
#
#                                               address region  24hours  \
# 64         Jl. Surya Permata III No.79 12, RT.14/RW.1  Barat        1
# 69               Jl. Kali Sekretaris No.20, RT.8/RW.5  Barat        1
# 80                           Jl. Mangga 19 No.2, RW.3  Barat        1
# 81            Jl. Duri Mas 1 Ujung No.rt8, RT.5/RW.10  Barat        1
# 82  Belakang Studio 5 Indosiar, Jl. Kali Sekretari...  Barat        1
# 62                Jl. Indraloka Raya No.28, RT.5/RW.6  Barat        1
# 51  Jl. Taman Ratu Raya Blk. BB1 No.19 10, RT.3/RW.13  Barat        1
#
#     parking  wifi  ac  toilet
# 64        1     1   1       1
# 69        1     1   1       1
# 80        1     1   1       1
# 81        1     1   1       1
# 82        1     1   1       1
# 62        1     1   1       1
# 51        1     1   1       1

# %%
# Muat model yang sudah dilatih
model.save('warkop_model')
model_saved = tf.keras.models.load_model('warkop_model')

# Buat converter TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model_saved)
tflite_model = converter.convert()

# Simpan model TFLite
with open('model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:absl:`24hours` is not a valid tf.function parameter name. Sanitizing to `arg_24hours`.
# WARNING:absl:`24hours` is not a valid tf.function parameter name. Sanitizing to `arg_24hours`.
# WARNING:absl:`24hours` is not a valid tf.function parameter name. Sanitizing to `arg_24hours`.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/keras/src/feature_column/base_feature_layer.py:129: serialize_feature_column (from tensorflow.python.feature_column.serialization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Keras preprocessing layers instead, either directly or via the `tf.keras.utils.FeatureSpace` utility. Each of `tf.feature_column.*` has a functional equivalent in `tf.keras.layers` for feature preprocessing when training a Keras model.

# %%
# Print TensorFlow version
print('TensorFlow version:', tf.__version__)

# Print TensorFlow Lite version
print('TensorFlow Lite version:', tf.__version__)
# Out:
# TensorFlow version: 2.15.0
# TensorFlow Lite version: 2.15.0

# %%
import tensorflow as tf

# Load TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="/content/model.tflite")
interpreter.allocate_tensors()

# Check input and output details (optional)
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Print input and output details
print("Input details:", input_details)
print("Output details:", output_details)
# Out:
# Input details: [{'name': 'args_0_4', 'index': 0, 'shape': array([1], dtype=int32), 'shape_signature': array([-1], dtype=int32), 'dtype': <class 'numpy.int64'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'args_0_9', 'index': 1, 'shape': array([1], dtype=int32), 'shape_signature': array([-1], dtype=int32), 'dtype': <class 'numpy.int64'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'args_0_11', 'index': 2, 'shape': array([1], dtype=int32), 'shape_signature': array([-1], dtype=int32), 'dtype': <class 'numpy.bytes_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'args_0_6', 'index': 3, 'shape': array([1], dtype=int32), 'shape_signature': array([-1], dtype=int32), 'dtype': <class 'numpy.bytes_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'args_0', 'index': 4, 'shape': array([1], dtype=int32), 'shape_signature': array([-1], dtype=int32), 'dtype': <class 'numpy.bytes_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'args_0_1', 'index': 5, 'shape': array([1], dtype=int32), 'shape_signature': array([-1], dtype=int32), 'dtype': <class 'numpy.int64'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'args_0_7', 'index': 6, 'shape': array([1], dtype=int32), 'shape_signature': array([-1], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'args_0_5', 'index': 7, 'shape': array([1], dtype=int32), 'shape_signature': array([-1], dtype=int32), 'dtype': <class 'numpy.int64'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'args_0_10', 'index': 8, 'shape': array([1], dtype=int32), 'shape_signature': array([-1], dtype=int32), 'dtype': <class 'numpy.bytes_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'args_0_2', 'index': 9, 'shape': array([1], dtype=int32), 'shape_signature': array([-1], dtype=int32), 'dtype': <class 'numpy.int64'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'args_0_3', 'index': 10, 'shape': array([1], dtype=int32), 'shape_signature': array([-1], dtype=int32), 'dtype': <class 'numpy.int64'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'args_0_8', 'index': 11, 'shape': array([1], dtype=int32), 'shape_signature': array([-1], dtype=int32), 'dtype': <class 'numpy.int64'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# Output details: [{'name': 'Identity', 'index': 27, 'shape': array([1, 1], dtype=int32), 'shape_signature': array([-1,  1], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %%
def preprocess_input(input_features, input_details):
    input_data = {}
    for detail in input_details:
        name = detail['name']
        dtype = detail['dtype']
        index = detail['index']

        if dtype == np.int64:
            input_data[name] = np.array([input_features.get(name, 0)], dtype=np.int64)
        elif dtype == np.float32:
            input_data[name] = np.array([input_features.get(name, 0)], dtype=np.float32)
        elif dtype == np.bytes_:
            input_data[name] = np.array([str(input_features.get(name, '')).encode('utf-8')], dtype=np.bytes_)
        else:
            raise ValueError(f"Unsupported dtype {dtype} for input {name}")
    return input_data

# %%
def recommend_warkop_tflite(input_features, facilities_set, top_k=100):
    warkop_df_copy = warkop_df.copy()

    predictions = []

    for i in range(len(warkop_df_copy)):
        row = warkop_df_copy.iloc[i]

        input_data = {facility: row[facility] for facility in facilities_set}
        input_data.update(input_features)

        processed_input = preprocess_input(input_data, input_details)

        for detail in input_details:
            interpreter.set_tensor(detail['index'], processed_input[detail['name']])

        interpreter.invoke()

        prediction = interpreter.get_tensor(output_details[0]['index'])

        predictions.append(prediction.flatten()[0])

    warkop_df_copy['prediction'] = predictions
    for facility in facilities_set:
        if input_features.get(facility, 1) == 1:
            warkop_df_copy = warkop_df_copy[warkop_df_copy[facility] == 1]

    sorted_warkops = warkop_df_copy.sort_values(by=['prediction', 'rating'], ascending=[False, False]).head(top_k)

    output_columns = ['name', 'rating', 'address', 'region'] + list(facilities_set)
    return sorted_warkops[output_columns]

# %%
# Example input features for recommendation
input_features = {
    "24hours": 1,
    "ac": 1,
    "wifi": 1,
    "parking": 1,
    "toilet": 1
}

# Region filter
region = 'Timur'
recommended_warkops = recommend_warkop_tflite(input_features, facilities_set)
filtered_warkops = recommended_warkops[recommended_warkops['region'] == region]

filtered_warkops
# Out:
#                     name  rating  \
# 135   Warkop Nyai Sinden     5.0
# 127  Warkop Maleber Jaya     4.5
# 96          Warkop SILMA     4.4
# 116         Warkop Teduh     4.4
#
#                                                address region  24hours  \
# 135                    Jl. H. Hanapi No.14, RT.14/RW.2  Timur        1
# 127  Jalan Cipinang Lontar No. 1 Rt.06/Rw.06 Cipina...  Timur        1
# 96             No., Jl. Dermaga Raya No.322, RT.7/RW.9  Timur        1
# 116  Jl. Cipinang Muara IV GG. Kutilang RT.002/011 ...  Timur        1
#
#      parking  wifi  ac  toilet
# 135        1     1   1       1
# 127        1     1   1       1
# 96         1     1   1       1
# 116        1     1   1       1
